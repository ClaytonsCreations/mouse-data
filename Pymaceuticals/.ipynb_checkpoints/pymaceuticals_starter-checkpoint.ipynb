# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1. Overall Drug Regimen Capomulin and Ramicane seem to be performing best in the mouse trial.
# 2. There were more male mice in the study then female mice.
# 3. The placebo and Stelasyn are getting similar results.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

# Display the data table for preview

mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mouse_count = len(mouse_study['Mouse ID'].unique())
f"Total Number of Mice: {mouse_count}"
# Out:
# 'Total Number of Mice: 249'

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_study_dups = mouse_study[mouse_study.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
mouse_study_dups.set_index('Mouse ID')
# Optional: Get all the data for the duplicate mouse ID.
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# g989               45.000000                 0
# g989               45.000000                 0
# g989               48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

mouse_study.drop(mouse_study.index[mouse_study['Mouse ID'] == 'g989'], inplace=True)

mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_mouse_count = len(mouse_study['Mouse ID'].unique())
f"Total Number of Mice: {new_mouse_count}"
# Out:
# 'Total Number of Mice: 248'

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

grouped_mouse_summary = mouse_study.groupby(['Drug Regimen'])
tumor_mean = grouped_mouse_summary['Tumor Volume (mm3)'].mean()
tumor_median = grouped_mouse_summary['Tumor Volume (mm3)'].median()
tumor_var = grouped_mouse_summary['Tumor Volume (mm3)'].var()
tumor_std = grouped_mouse_summary['Tumor Volume (mm3)'].std()
tumor_sem = grouped_mouse_summary['Tumor Volume (mm3)'].sem()


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

grouped_mouse_summary_df = pd.DataFrame({'Mean': tumor_mean,'Median' : tumor_median, 'Variance' : tumor_var,
                        'Standard Deviation' : tumor_std, 'SEM' : tumor_sem})
grouped_mouse_summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

grouped_mouse_agg = mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
grouped_mouse_agg
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
mouse_study.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

drug_and_timepoints = mouse_study.groupby(['Drug Regimen'])['Timepoint'].count()
drug_and_timepoints
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     148
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Timepoint, dtype: int64

# %%
drug_and_timepoints.plot(kind='bar', figsize=(7,7))
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
time_regimen = mouse_study['Drug Regimen'].value_counts()

plt.title('Timepoints Count per Regimen')
plt.ylabel('Timepoints')
plt.xticks(rotation = 45)
plt.xlabel('Drug Regimen')
plt.bar(time_regimen.index.values, time_regimen)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
male_female = mouse_study.groupby(['Sex'])['Mouse ID'].count()

plt.title('Timepoints Count per Regimen')

male_female.plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
male_female = mouse_study.groupby(['Sex'])['Mouse ID'].count()
labels = ['Female','Male']

plt.title('Timepoints Count per Regimen')

plt.pie(male_female, autopct='%1.1f%%', labels=labels)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
mouse_volume = mouse_study.groupby(['Mouse ID'])['Timepoint'].max()
mouse_volume = mouse_volume.reset_index()

drug_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Start by getting the last (greatest) timepoint for each mouse

merge_volume_timepoint = mouse_volume.merge(mouse_study, on=['Mouse ID', 'Timepoint'], how='left')

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_tumor_volume = merge_volume_timepoint.loc[merge_volume_timepoint['Drug Regimen'].isin(drug_list)]

final_tumor_volume
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 3       a275         45     Ceftamin  Female          20          28
# 6       a411         45     Ramicane    Male           3          22
# 7       a444         45     Ramicane  Female          10          25
# ..       ...        ...          ...     ...         ...         ...
# 238     y769         45     Ceftamin  Female           6          27
# 239     y793         45    Capomulin    Male          17          17
# 240     y865         45     Ceftamin    Male          23          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
final_tumor_volume.boxplot(by ='Drug Regimen', column =['Tumor Volume (mm3)'], grid = False)
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
final_volume = final_tumor_volume['Tumor Volume (mm3)']

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = final_volume.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of tumor volume is: {lowerq}")
print(f"The upper quartile of tumor volume is: {upperq}")
print(f"The interquartile range of tumor volume is: {iqr}")
print(f"The the median of tumor volume is: {quartiles[0.5]} ")

    
# Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of tumor volume is: 37.1877438025
# The upper quartile of tumor volume is: 59.930261755
# The interquartile range of tumor volume is: 22.742517952499995
# The the median of tumor volume is: 45.0
# Values below 3.0739668737500097 could be outliers.
# Values above 94.04403868374999 could be outliers.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin = mouse_study.loc[mouse_study['Mouse ID'] == 'y793',:]

x_axis = capomulin['Timepoint'] 

y_axis = capomulin['Tumor Volume (mm3)'] 

plt.title('Capomulin treatmeant of mouse y793')

plt.plot(x_axis, y_axis) 
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
drug = ['Capomulin']
capomulin_average = merge_volume_timepoint.loc[merge_volume_timepoint['Drug Regimen'].isin(drug)]
capomulin_average.plot(kind='scatter',x='Tumor Volume (mm3)',y='Weight (g)',color='red')
plt.title('Capomulin avg. Tumor Volume vs. Weight')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
weight = capomulin_average.iloc[:,5]
tumor = capomulin_average.iloc[:,6]
correlation = st.pearsonr(weight, tumor)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.88

# %%
plt.scatter(weight, tumor)
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.88

# %%
x_values = capomulin_average['Weight (g)']
y_values = capomulin_average['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weight, tumor)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="Red")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()
